# %% [markdown]
# #**PANDAS**
#
#
# Open source
#
# *   I/O from flat files
# *   Easy handling of missing data
# *   Automatic data alignment
#
# *   Slicing,indexing, subsetting
#
# *   Merging and joining datasets

# %% [markdown]
# ?3) Create a dataframe with just the city and state columns from the ufo dataset

# %% [markdown]
# ![Screenshot 2021-07-11 at 10.10.50 AM.png](data:image/png;base64,...)
#
# ?7) Create the above dataframe using dictionaries
#
#     1. Make id the index of the dataframe.

# %% [markdown]
# ![Screenshot 2021-07-11 at 10.21.26 AM.png](data:image/png;base64,...)
#
# ?8)Create the above dataframe using dictionaries.

# %% [markdown]
# ?9) Create the dataframe in qstn 8 using list of lists.

# %% [markdown]
# ?10) Create a dataframe using a matrix of order 4X2.

# %% [markdown]
# ![Screenshot 2021-07-11 at 10.57.13 AM.png](data:image/png;base64,...)
#
# ?11) Create the above series and add it as the third column of dataframe in qstn 8

# %% [markdown]
# ?12) Create the dataframe in qstn 9 using list of dictionaries.

# %% [markdown]
# ?13) Open the automobile data from google drive

# %% [markdown]
# ?14) What will happen after the following code?
#
#
# ```
# def revised_profit(revenue, budget):
#   if revenue > 0:
#     new_profit = revenue - budget
#   else:
#     new_profit = np.nan
#
#   return new_profit
#
#
#
#   df['new_profit'] = df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis=1)
# ```

# %% [markdown]
# ?15) How do you save a file?
