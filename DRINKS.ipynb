# %%
import pandas as pd

# %% [markdown]
# ?5) Open the table in https://bit.ly/drinksbycountry and assign it to variable drinks
#
#
#     1. Display the datatypes in the table
#     2. Change the datatype of the beer_servings column to float
#     3. Find the average beer_servings per continent
#     4. Find the min beer_servings per continent
#     5. Find the max beer_servings per continent
#     6. Display the count,min,max and mean of beer_servings for each continent as a datafram
#     7. Display the mean for all columns in the table continent wise and plot it as a bar chart
#     8. Find the average beer_servings just for Africa
#     9. Set column country as the index of the dataframe and find the beer servings for Brazil using the loc method.
#     10. Remove the heading country from the index column.
#     11. Reverse steps 9 and 10
#     12. Find the 25th percentile of beer servings
#     13. Display as an array, just the number of occurances of different values in continent column
#     14. Display the number of occurances of 'Africa' in column continent
#     15. Sort the contents of value_counts() series of continent column wrt the index
#     16. Create a dataseries people with population data Albania:3000000 and Andorra:85000. Name the series as population.
#     17. Find the total beer servings in Albania and Andorra using the population dataseries.
#     18. Add the series population as a column of drinks dataframe
#     19. Change setting to display all rows of drinks dataframe.
#     20. **Reset the above operation.**---------------------------
#     21. Change setting to display all columns of drinks dataframe.
#     22. **Reset the above operation.**--------------------------------
#     23. Create a column x with values 1000 times values in wine_servings and column y with values 1000 times the values in total_litres_of_pure_alchohol
#     24. Display the contents of columns x and y separated by commas.eg: 29,200
#     25. Reset all the display options.

# %%
drinks = pd.read_table('https://bit.ly/drinksbycountry',sep = ',')

# %%
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %% [markdown]
# 1)Display the datatypes in the table

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# 2) Change the datatype of the beer_servings column to float

# %%
drinks.beer_servings = drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# **OR**

# %%
drinks = pd.read_csv('https://bit.ly/drinksbycountry',dtype={'beer_servings':float})

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# 3)

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# 4)

# %%
drinks.groupby('continent').beer_servings.min()
# Out:
# continent
# Africa            0.0
# Asia              0.0
# Europe            0.0
# North America     1.0
# Oceania           0.0
# South America    93.0
# Name: beer_servings, dtype: float64

# %% [markdown]
# 5)

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376.0
# Asia             247.0
# Europe           361.0
# North America    285.0
# Oceania          306.0
# South America    333.0
# Name: beer_servings, dtype: float64

# %% [markdown]
# 6)

# %%
drinks.groupby('continent').beer_servings.agg(['min','max','count','mean'])
# Out:
#                 min    max  count        mean
# continent
# Africa          0.0  376.0     53   61.471698
# Asia            0.0  247.0     44   37.045455
# Europe          0.0  361.0     45  193.777778
# North America   1.0  285.0     23  145.434783
# Oceania         0.0  306.0     16   89.687500
# South America  93.0  333.0     12  175.083333

# %% [markdown]
# 7)

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').mean().plot(kind='bar')

# %% [markdown]
# 8)

# %%
drinks.groupby('continent').beer_servings.mean()['Africa']
# Out:
# 61.471698113207545

# %% [markdown]
# **OR**

# %%
drinks.groupby('continent').beer_servings.mean().Africa
# Out:
# 61.471698113207545

# %% [markdown]
# **OR**

# %%
drinks.loc[drinks.continent=='Africa',:].beer_servings.mean()
# Out:
# 61.471698113207545

# %% [markdown]
# 9)

# %%
drinks.set_index('country',inplace=True)

# %%
drinks.head()
# Out:
#              beer_servings  ...  continent
# country                     ...
# Afghanistan            0.0  ...       Asia
# Albania               89.0  ...     Europe
# Algeria               25.0  ...     Africa
# Andorra              245.0  ...     Europe
# Angola               217.0  ...     Africa
#
# [5 rows x 5 columns]

# %%
drinks.loc['Brazil','beer_servings']
# Out:
# 245.0

# %% [markdown]
# 10)

# %%
drinks.index.name = None

# %%
drinks.head()
# Out:
#              beer_servings  ...  continent
# Afghanistan            0.0  ...       Asia
# Albania               89.0  ...     Europe
# Algeria               25.0  ...     Africa
# Andorra              245.0  ...     Europe
# Angola               217.0  ...     Africa
#
# [5 rows x 5 columns]

# %% [markdown]
# 11)

# %%
drinks.index.name = 'country'

# %%
drinks.head()
# Out:
#              beer_servings  ...  continent
# country                     ...
# Afghanistan            0.0  ...       Asia
# Albania               89.0  ...     Europe
# Algeria               25.0  ...     Africa
# Andorra              245.0  ...     Europe
# Angola               217.0  ...     Africa
#
# [5 rows x 5 columns]

# %%
drinks.reset_index(inplace=True)

# %%
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan            0.0  ...                           0.0       Asia
# 1      Albania           89.0  ...                           4.9     Europe
# 2      Algeria           25.0  ...                           0.7     Africa
# 3      Andorra          245.0  ...                          12.4     Europe
# 4       Angola          217.0  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %% [markdown]
# 12)

# %%
drinks.beer_servings.describe()['25%']
# Out:
# 20.0

# %% [markdown]
# **OR**

# %%
drinks.describe().loc['25%','beer_servings']
# Out:
# 20.0

# %% [markdown]
# 13)

# %%
drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12])

# %% [markdown]
# 14)

# %%
drinks[drinks.continent == 'Africa'].continent.value_counts()
# Out:
# Africa    53
# Name: continent, dtype: int64

# %% [markdown]
# **OR**

# %%
drinks.continent.isin(['Africa']).sum()
# Out:
# 53

# %% [markdown]
# **OR**

# %%
drinks.continent.value_counts().Africa
# Out:
# 53

# %% [markdown]
# 15)

# %%
drinks.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %% [markdown]
# ##**Alignment in Pandas**

# %% [markdown]
# 16)

# %%
people = pd.Series({'Albania':3000000,'Andorra':85000},name='population')

# %%
people
# Out:
# Albania    3000000
# Andorra      85000
# Name: population, dtype: int64

# %% [markdown]
# 17)

# %%
drinks.set_index('country',inplace=True) ## This is to be done to match indices

# %%
drinks.beer_servings*people
# Out:
# Afghanistan            NaN
# Albania        267000000.0
# Algeria                NaN
# Andorra         20825000.0
# Angola                 NaN
#                   ...
# Venezuela              NaN
# Vietnam                NaN
# Yemen                  NaN
# Zambia                 NaN
# Zimbabwe               NaN
# Length: 193, dtype: float64

# %% [markdown]
# 18)

# %%
pd.concat([drinks,people],axis=1)
# Out:
#              beer_servings  spirit_servings  ...      continent  population
# Afghanistan            0.0                0  ...           Asia         NaN
# Albania               89.0              132  ...         Europe   3000000.0
# Algeria               25.0                0  ...         Africa         NaN
# Andorra              245.0              138  ...         Europe     85000.0
# Angola               217.0               57  ...         Africa         NaN
# ...                    ...              ...  ...            ...         ...
# Venezuela            333.0              100  ...  South America         NaN
# Vietnam              111.0                2  ...           Asia         NaN
# Yemen                  6.0                0  ...           Asia         NaN
# Zambia                32.0               19  ...         Africa         NaN
# Zimbabwe              64.0               18  ...         Africa         NaN
#
# [193 rows x 6 columns]

# %% [markdown]
# 19)

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.set_option('display.max_rows',None)

# %%
drinks
# Out:
#                               beer_servings  ...      continent
# country                                      ...
# Afghanistan                             0.0  ...           Asia
# Albania                                89.0  ...         Europe
# Algeria                                25.0  ...         Africa
# Andorra                               245.0  ...         Europe
# Angola                                217.0  ...         Africa
# Antigua & Barbuda                     102.0  ...  North America
# Argentina                             193.0  ...  South America
# Armenia                                21.0  ...         Europe
# Australia                             261.0  ...        Oceania
# Austria                               279.0  ...         Europe
# Azerbaijan                             21.0  ...         Europe
# Bahamas                               122.0  ...  North America
# Bahrain                                42.0  ...           Asia
# ...

# %% [markdown]
# 20)Change setting to display all columns of drinks dataframe.

# %%
pd.get_option('display.max_columns')
# Out:
# 0

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# 21) Create a column x with values 1000 times values in wine_servings and column y with values 1000 times the values in total_litres_of_pure_alchohol

# %%
drinks['x'] = 1000 * drinks.wine_servings

# %%
drinks['y'] = 1000 * drinks.total_litres_of_pure_alcohol

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan            0.0                0              0
# Albania               89.0              132             54
# Algeria               25.0                0             14
# Andorra              245.0              138            312
# Angola               217.0               57             45
#
#              total_litres_of_pure_alcohol continent       x        y
# country
# Afghanistan                           0.0      Asia       0      0.0
# Albania                               4.9    Europe   54000   4900.0
# Algeria                               0.7    Africa   14000    700.0
# Andorra                              12.4    Europe  312000  12400.0
# Angola                                5.9    Africa   45000   5900.0

# %% [markdown]
# 22)Display the contents of columns x and y separated by commas.eg: 29,200

# %%
pd.set_option('display.float_format','{:,}'.format)

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan            0.0                0              0
# Albania               89.0              132             54
# Algeria               25.0                0             14
# Andorra              245.0              138            312
# Angola               217.0               57             45
#
#              total_litres_of_pure_alcohol continent       x        y
# country
# Afghanistan                           0.0      Asia       0      0.0
# Albania                               4.9    Europe   54000  4,900.0
# Algeria                               0.7    Africa   14000    700.0
# Andorra                              12.4    Europe  312000 12,400.0
# Angola                                5.9    Africa   45000  5,900.0

# %% [markdown]
# #**did not affect x coz, x is in int format.**

# %% [markdown]
# 23)Reset all the display options.

# %%
pd.reset_option('all')
# Out:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# /usr/local/lib/python3.7/dist-packages/pandas/_config/config.py:622: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)
