# %%
import pandas as pd

# %% [markdown]
# ?2) Open the table in address: http://bit.ly/uforeports . Note: It is a CSV file. Assign the dataframe to variable ufo
#
#
#     1.   Select out City column as a data series from the table
#     2.   Select out Colors Reported column as a data series from the table
#     3.   Create a column named Location by merging values in column City and State separated by a comma like Ithaca, NY
#     4.   Create a list of all column labels
#     5.   Change the column names Colors Reported and Shape Reported to Colors_Reported and Shape_Reported temporarily
#     6.   Change the column names Colors Reported and Shape Reported to Colors_Reported and Shape_Reported permanently
#     7.   Check for missing values in the tail part of the dataframe.
#     8.   Display the number of missing values in each column of the dataframe.
#     9.   Display the details of instances where there is no info for city column
#     10.  Drop the rows in which any info is missing
#     11.  Drop the rows in which all the values are missing
#     12.  Drop the rows in which City or Shape Reported info are missing
#     13.  Drop the rows in which City and Shape Reported info are missing
#
#     135.  Drop the rows in which more than 1 value is missing.
#
#     14.  Display the value counts for Shape Reported column including the NaN values
#     15.  Replace the NaN values with string VARIABLE
#     16.  VIP QSTN:Select the first 3 rows using loc method. Include all the columns.
#     17.  Display all rows with columns City and State using loc method
#     18.  Display all rows with columns City through State using loc method
#     19.  Display all info for City 'Oakland' using loc method without changing the index row.
#     20.  Repeat 16,17,18 and 19 using iloc method
#     21.  Convert the time column to actual time format
#     22.  Pull out the hours from the column Time
#     23.  Show the info for ufo sightings after Jan 1,1999.
#     24.  Show the latest time of ufo sighting
#     25.  Show the time difference between the oldest and newest ufo sightings.
#     26.  Show the time difference in days between the oldest and newest ufo sightings.
#     27.  Show a line plot of ufo sightings by year.

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# 1.   Select out City column as a data series from the table

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %% [markdown]
# 2.   Select out Colors Reported column as a data series from the table

# %%
ufo['Colors Reported']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18236    NaN
# 18237    NaN
# 18238    NaN
# 18239    RED
# 18240    NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %% [markdown]
# 3.   Create a column named Location by merging values in column City and State separated by a comma like Ithaca, NY

# %%
ufo['Location'] = ufo.City + ',' + ufo.State

# %%
ufo.head()
# Out:
#                    City  ...                 Location
# 0                Ithaca  ...                Ithaca,NY
# 1           Willingboro  ...           Willingboro,NJ
# 2               Holyoke  ...               Holyoke,CO
# 3               Abilene  ...               Abilene,KS
# 4  New York Worlds Fair  ...  New York Worlds Fair,NY
#
# [5 rows x 6 columns]

# %% [markdown]
# 4.   Create a list of all column labels

# %%
list(ufo.columns)
# Out:
# ['City', 'Colors Reported', 'Shape Reported', 'State', 'Time', 'Location']

# %% [markdown]
# 5.   Change the column names Colors Reported and Shape Reported to Colors_Reported and Shape_Reported temporarily
# 6.   Change the column names Colors Reported and Shape Reported to Colors_Reported and Shape_Reported permanently

# %% [markdown]
# **Method-1**

# %%
ufo.rename(columns= {'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'} )
# Out:
#                        City  ...                 Location
# 0                    Ithaca  ...                Ithaca,NY
# 1               Willingboro  ...           Willingboro,NJ
# 2                   Holyoke  ...               Holyoke,CO
# 3                   Abilene  ...               Abilene,KS
# 4      New York Worlds Fair  ...  New York Worlds Fair,NY
# ...                     ...  ...                      ...
# 18236            Grant Park  ...            Grant Park,IL
# 18237           Spirit Lake  ...           Spirit Lake,IA
# 18238           Eagle River  ...           Eagle River,WI
# 18239           Eagle River  ...           Eagle River,WI
# 18240                  Ybor  ...                  Ybor,FL
#
# [18241 rows x 6 columns]

# %%
ufo.rename(columns= {'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'}, inplace = True)  # inplace = True set it permanently

# %% [markdown]
# **Method-2**

# %%
ufo_col = ['City','Colors_Reported','Shape_Reported','State','Time','Location']
ufo.columns = ufo_col # This changes the names permanently

# %% [markdown]
# **Method-3**

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', names = ufo_col)

# %% [markdown]
# **Method-4**

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.columns = ufo.columns.str.replace(' ','_')

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %% [markdown]
# 7.   Check for missing values in the tail part of the dataframe.

# %% [markdown]
# **Method-1**

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %% [markdown]
# **Method-2**

# %%
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %% [markdown]
# 8.   Display the number of missing values in each column of the dataframe.

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %% [markdown]
# 9.   Display the details of instances where there is no info for city column

# %%
ufo.loc[ufo.City.isnull(),:]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %% [markdown]
# 10.  Drop the rows in which any info is missing
#     11.  Drop the rows in which all the values are missing
#     12.  Drop the rows in which City or Shape Reported info are missing
#     13.  Drop the rows in which City and Shape Reported info are missing

# %%
ufo.dropna(how='any')
# Out:
#                City Colors Reported Shape Reported State              Time
# 12           Belton             RED         SPHERE    SC   6/30/1939 20:00
# 19       Bering Sea             RED          OTHER    AK   4/30/1943 23:00
# 36       Portsmouth             RED      FORMATION    VA    7/10/1945 1:30
# 44        Blairsden           GREEN         SPHERE    CA   6/30/1946 19:00
# 82         San Jose            BLUE        CHEVRON    CA   7/15/1947 21:00
# ...             ...             ...            ...   ...               ...
# 18213      Pasadena           GREEN       FIREBALL    CA  12/28/2000 19:10
# 18216  Garden Grove          ORANGE          LIGHT    CA  12/29/2000 16:10
# 18220   Shasta Lake            BLUE           DISK    CA  12/29/2000 20:30
# 18233     Anchorage             RED        VARIOUS    AK  12/31/2000 21:00
# 18239   Eagle River             RED          LIGHT    WI  12/31/2000 23:45
#
# [2486 rows x 5 columns]

# %% [markdown]
#  11.  Drop the rows in which all the values are missing

# %%
ufo.dropna(how='all')
# Out:
#                        City Colors Reported  ... State              Time
# 0                    Ithaca             NaN  ...    NY    6/1/1930 22:00
# 1               Willingboro             NaN  ...    NJ   6/30/1930 20:00
# 2                   Holyoke             NaN  ...    CO   2/15/1931 14:00
# 3                   Abilene             NaN  ...    KS    6/1/1931 13:00
# 4      New York Worlds Fair             NaN  ...    NY   4/18/1933 19:00
# ...                     ...             ...  ...   ...               ...
# 18236            Grant Park             NaN  ...    IL  12/31/2000 23:00
# 18237           Spirit Lake             NaN  ...    IA  12/31/2000 23:00
# 18238           Eagle River             NaN  ...    WI  12/31/2000 23:45
# 18239           Eagle River             RED  ...    WI  12/31/2000 23:45
# 18240                  Ybor             NaN  ...    FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %% [markdown]
# 12.  Drop the rows in which City or Shape Reported info are missing

# %%
ufo.dropna(subset = ['City','Shape Reported'],how='any')
# Out:
#                        City Colors Reported  ... State              Time
# 0                    Ithaca             NaN  ...    NY    6/1/1930 22:00
# 1               Willingboro             NaN  ...    NJ   6/30/1930 20:00
# 2                   Holyoke             NaN  ...    CO   2/15/1931 14:00
# 3                   Abilene             NaN  ...    KS    6/1/1931 13:00
# 4      New York Worlds Fair             NaN  ...    NY   4/18/1933 19:00
# ...                     ...             ...  ...   ...               ...
# 18234              Capitola             NaN  ...    CA  12/31/2000 22:00
# 18236            Grant Park             NaN  ...    IL  12/31/2000 23:00
# 18237           Spirit Lake             NaN  ...    IA  12/31/2000 23:00
# 18239           Eagle River             RED  ...    WI  12/31/2000 23:45
# 18240                  Ybor             NaN  ...    FL  12/31/2000 23:59
#
# [15576 rows x 5 columns]

# %% [markdown]
# 13.  Drop the rows in which City and Shape Reported info are missing

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all')
# Out:
#                        City Colors Reported  ... State              Time
# 0                    Ithaca             NaN  ...    NY    6/1/1930 22:00
# 1               Willingboro             NaN  ...    NJ   6/30/1930 20:00
# 2                   Holyoke             NaN  ...    CO   2/15/1931 14:00
# 3                   Abilene             NaN  ...    KS    6/1/1931 13:00
# 4      New York Worlds Fair             NaN  ...    NY   4/18/1933 19:00
# ...                     ...             ...  ...   ...               ...
# 18236            Grant Park             NaN  ...    IL  12/31/2000 23:00
# 18237           Spirit Lake             NaN  ...    IA  12/31/2000 23:00
# 18238           Eagle River             NaN  ...    WI  12/31/2000 23:45
# 18239           Eagle River             RED  ...    WI  12/31/2000 23:45
# 18240                  Ybor             NaN  ...    FL  12/31/2000 23:59
#
# [18237 rows x 5 columns]

# %% [markdown]
# 135.  Drop the rows in which more than 1 value is missing.

# %%
ufo.dropna(thresh=2)
# Out:
#                        City Colors Reported  ... State              Time
# 0                    Ithaca             NaN  ...    NY    6/1/1930 22:00
# 1               Willingboro             NaN  ...    NJ   6/30/1930 20:00
# 2                   Holyoke             NaN  ...    CO   2/15/1931 14:00
# 3                   Abilene             NaN  ...    KS    6/1/1931 13:00
# 4      New York Worlds Fair             NaN  ...    NY   4/18/1933 19:00
# ...                     ...             ...  ...   ...               ...
# 18236            Grant Park             NaN  ...    IL  12/31/2000 23:00
# 18237           Spirit Lake             NaN  ...    IA  12/31/2000 23:00
# 18238           Eagle River             NaN  ...    WI  12/31/2000 23:45
# 18239           Eagle River             RED  ...    WI  12/31/2000 23:45
# 18240                  Ybor             NaN  ...    FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %% [markdown]
# 14.  Display the value counts for Shape Reported column including the NaN values

# %%
ufo['Shape Reported'].value_counts(dropna=False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# DOME            1
# FLARE           1
# HEXAGON         1
# PYRAMID         1
# Name: Shape Reported, dtype: int64

# %% [markdown]
#  15.  Replace the NaN values with string VARIABLE

# %%
ufo.fillna(value='VARIABLE',inplace = True)

# %%
ufo['Shape Reported'].value_counts(dropna=False)
# Out:
# LIGHT        2803
# VARIABLE     2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# FLARE           1
# DOME            1
# HEXAGON         1
# PYRAMID         1
# Name: Shape Reported, dtype: int64

# %% [markdown]
#     16.  VIP QSTN:Select the first 3 rows using loc method. Include all the columns.

# %%
ufo.loc[:2,:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca        VARIABLE       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro        VARIABLE          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke        VARIABLE           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# 17.  Display all rows with columns City and State using loc method

# %%
ufo.loc[:,['City','State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 18236            Grant Park    IL
# 18237           Spirit Lake    IA
# 18238           Eagle River    WI
# 18239           Eagle River    WI
# 18240                  Ybor    FL
#
# [18241 rows x 2 columns]

# %% [markdown]
# 18.  Display all rows with columns City through State using loc method

# %%
ufo.loc[:,'City':'State']
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca        VARIABLE       TRIANGLE    NY
# 1               Willingboro        VARIABLE          OTHER    NJ
# 2                   Holyoke        VARIABLE           OVAL    CO
# 3                   Abilene        VARIABLE           DISK    KS
# 4      New York Worlds Fair        VARIABLE          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park        VARIABLE       TRIANGLE    IL
# 18237           Spirit Lake        VARIABLE           DISK    IA
# 18238           Eagle River        VARIABLE       VARIABLE    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor        VARIABLE           OVAL    FL
#
# [18241 rows x 4 columns]

# %% [markdown]
#  19.  Display all info for City 'Oakland' using loc method without changing the index row.

# %%
ufo.loc[ufo.City == 'Oakland',:]
# Out:
#           City Colors Reported Shape Reported State              Time
# 1694   Oakland        VARIABLE          CIGAR    CA   7/21/1968 14:00
# 2144   Oakland        VARIABLE           DISK    CA    8/19/1971 0:00
# 4686   Oakland        VARIABLE          LIGHT    MD     6/1/1982 0:00
# 7293   Oakland        VARIABLE          LIGHT    CA   3/28/1994 17:00
# 8488   Oakland        VARIABLE       VARIABLE    CA   8/10/1995 21:45
# 8768   Oakland        VARIABLE       VARIABLE    CA  10/10/1995 22:40
# 10816  Oakland        VARIABLE          LIGHT    OR   10/1/1997 21:30
# 10948  Oakland        VARIABLE           DISK    CA  11/14/1997 19:55
# 11045  Oakland        VARIABLE       TRIANGLE    CA   12/10/1997 1:30
# 12322  Oakland        VARIABLE       FIREBALL    CA   10/9/1998 19:40
# 12941  Oakland        VARIABLE       CYLINDER    CA   1/23/1999 21:30
# 16803  Oakland        VARIABLE       TRIANGLE    MD    7/4/2000 23:00
# ...

# %% [markdown]
#  20.  Repeat 16,17,18 and 19 using iloc method

# %%
ufo.iloc[:3,:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca        VARIABLE       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro        VARIABLE          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke        VARIABLE           OVAL    CO  2/15/1931 14:00

# %%
ufo.iloc[:,[1,4]]
# Out:
#       Colors Reported              Time
# 0            VARIABLE    6/1/1930 22:00
# 1            VARIABLE   6/30/1930 20:00
# 2            VARIABLE   2/15/1931 14:00
# 3            VARIABLE    6/1/1931 13:00
# 4            VARIABLE   4/18/1933 19:00
# ...               ...               ...
# 18236        VARIABLE  12/31/2000 23:00
# 18237        VARIABLE  12/31/2000 23:00
# 18238        VARIABLE  12/31/2000 23:45
# 18239             RED  12/31/2000 23:45
# 18240        VARIABLE  12/31/2000 23:59
#
# [18241 rows x 2 columns]

# %%
ufo.iloc[:,1:4]
# Out:
#       Colors Reported Shape Reported State
# 0            VARIABLE       TRIANGLE    NY
# 1            VARIABLE          OTHER    NJ
# 2            VARIABLE           OVAL    CO
# 3            VARIABLE           DISK    KS
# 4            VARIABLE          LIGHT    NY
# ...               ...            ...   ...
# 18236        VARIABLE       TRIANGLE    IL
# 18237        VARIABLE           DISK    IA
# 18238        VARIABLE       VARIABLE    WI
# 18239             RED          LIGHT    WI
# 18240        VARIABLE           OVAL    FL
#
# [18241 rows x 3 columns]

# %%
ufo.iloc[ufo.City=='Oakland',:]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-45-3cad455d3f76> in <module>()
# ----> 1 ufo.iloc[ufo.City=='Oakland',:]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
# ...

# %% [markdown]
# 21.  Convert the time column to actual time format

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca        VARIABLE       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro        VARIABLE          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke        VARIABLE           OVAL    CO  2/15/1931 14:00
# 3               Abilene        VARIABLE           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair        VARIABLE          LIGHT    NY  4/18/1933 19:00

# %%
ufo.Time = pd.to_datetime(ufo.Time)

# %%
ufo.head()
# Out:
#                    City Colors Reported  ... State                Time
# 0                Ithaca        VARIABLE  ...    NY 1930-06-01 22:00:00
# 1           Willingboro        VARIABLE  ...    NJ 1930-06-30 20:00:00
# 2               Holyoke        VARIABLE  ...    CO 1931-02-15 14:00:00
# 3               Abilene        VARIABLE  ...    KS 1931-06-01 13:00:00
# 4  New York Worlds Fair        VARIABLE  ...    NY 1933-04-18 19:00:00
#
# [5 rows x 5 columns]

# %% [markdown]
# #**Pandas strftime documentation**

# %% [markdown]
# 22.  Pull out the hours from the column Time

# %%
ufo.Time.dt.hour
# Out:
# 0        22
# 1        20
# 2        14
# 3        13
# 4        19
#          ..
# 18236    23
# 18237    23
# 18238    23
# 18239    23
# 18240    23
# Name: Time, Length: 18241, dtype: int64

# %% [markdown]
# 23.  Show the info for ufo sightings after Jan 1,1999.

# %%
ts = pd.to_datetime('1/1/1999')

# %%
ufo.loc[ufo.Time >= ts,:]
# Out:
#                     City Colors Reported  ... State                Time
# 12832          Loma Rica        VARIABLE  ...    CA 1999-01-01 02:30:00
# 12833            Bauxite        VARIABLE  ...    AR 1999-01-01 03:00:00
# 12834           Florence        VARIABLE  ...    SC 1999-01-01 14:00:00
# 12835       Lake Henshaw        VARIABLE  ...    CA 1999-01-01 15:00:00
# 12836  Wilmington Island        VARIABLE  ...    GA 1999-01-01 17:15:00
# ...                  ...             ...  ...   ...                 ...
# 18236         Grant Park        VARIABLE  ...    IL 2000-12-31 23:00:00
# 18237        Spirit Lake        VARIABLE  ...    IA 2000-12-31 23:00:00
# 18238        Eagle River        VARIABLE  ...    WI 2000-12-31 23:45:00
# 18239        Eagle River             RED  ...    WI 2000-12-31 23:45:00
# 18240               Ybor        VARIABLE  ...    FL 2000-12-31 23:59:00
#
# [5409 rows x 5 columns]

# %% [markdown]
# 24.  Show the latest time of ufo sighting

# %%
ufo.Time.max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %% [markdown]
# 25.  Show the time difference between the oldest and newest ufo sightings.

# %%
ufo.Time.max() - ufo.Time.min()
# Out:
# Timedelta('25781 days 01:59:00')

# %% [markdown]
# 26.  Show the time difference in days between the oldest and newest ufo sightings.

# %%
(ufo.Time.max() - ufo.Time.min()).days
# Out:
# 25781

# %% [markdown]
# 27.  Show a line plot of ufo sightings by year.

# %%
ufo['Year'] = ufo.Time.dt.year

# %%
ufo.head()
# Out:
#                    City Colors Reported  ...                Time  Year
# 0                Ithaca        VARIABLE  ... 1930-06-01 22:00:00  1930
# 1           Willingboro        VARIABLE  ... 1930-06-30 20:00:00  1930
# 2               Holyoke        VARIABLE  ... 1931-02-15 14:00:00  1931
# 3               Abilene        VARIABLE  ... 1931-06-01 13:00:00  1931
# 4  New York Worlds Fair        VARIABLE  ... 1933-04-18 19:00:00  1933
#
# [5 rows x 6 columns]

# %%
# %matplotlib inline

# %%
ufo.Year.value_counts().sort_index().plot()
