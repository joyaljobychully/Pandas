# %% [markdown]
# ## <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# # <b> Problem 1: Import Pandas and Numpy in the notebook </b>
# # <b> Problem 2 : Load the automobile_data.csv kept in the shared folder
# # <b>Problem 4 : You need to clean the data a little bit now. Replace all column values with the values <code>?</code> and <code>n.a</code> with <code>NaN</code>
# # <b>Problem 5 : Print the company name which manufactured the most expensive car. Also print the price of the most expensive car
# # <b>Problem 6 : Calculate maximum horsepowers for each company. </b>
# # <b> Problem 7 : Print the total number of cars manufactured by each company
# # <b> Problem 8 : Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled </b>
# # <b>Problem 9 : Sort the dataframe by car and price columns
# # <b> Problem 10 : Create a new column which stores the number of doors in a car as integers.
# # <b>Problem 11 : Concatenate the two data frames given below firstly row wise and secondly column wise.</b>
#
# <code>GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}</code>
#
# <code>japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}</code>

# %% [markdown]
# # <b> Problem 1: Import Pandas and Numpy in the notebook </b>

# %%
# Import statements
import numpy as np
import pandas as pd

# %% [markdown]
# # <b> Problem 2 : Load the automobile_data.csv kept in the shared folder

# %%
# Mount your drive and read the csv file. Make sure you are using the correct file path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
auto = pd.read_csv('/content/drive/MyDrive/Copy of automobile_data.csv')

# %% [markdown]
# # <b> Problem 3 : Do a basic inspection and print the first and last 15 rows of your dataframe

# %%
auto
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3                 ?  alfa-romero  ...       21          27  13495
# 1            3                 ?  alfa-romero  ...       21          27  16500
# 2            1                 ?  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
# Your code here

auto.head(15)
# Out:
#     symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0           3                 ?  alfa-romero  ...       21          27  13495
# 1           3                 ?  alfa-romero  ...       21          27  16500
# 2           1                 ?  alfa-romero  ...       19          26  16500
# 3           2               164         audi  ...       24          30  13950
# 4           2               164         audi  ...       18          22  17450
# 5           2                 ?         audi  ...       19          25  15250
# 6           1               158         audi  ...       19          25  17710
# 7           1                 ?         audi  ...       19          25  18920
# 8           1               158         audi  ...       17          20  23875
# 9           0                 ?         audi  ...       16          22      ?
# 10          2               192          bmw  ...       23          29  16430
# 11          0               192          bmw  ...       23          29  16925
# 12          0               188          bmw  ...       21          28  20970
# 13          0               188          bmw  ...       21          28  21105
# 14          1                 ?          bmw  ...       20          25  24565
#
# [15 rows x 26 columns]

# %%
auto.tail(50)
# Out:
#      symboling normalized-losses        make  ... city-mpg highway-mpg    price
# 155        0.0                91      toyota  ...     27.0        32.0   8778.0
# 156        0.0                91      toyota  ...     30.0        37.0   6938.0
# 157        0.0                91      toyota  ...     30.0        37.0   7198.0
# 158        0.0                91      toyota  ...     34.0        36.0   7898.0
# 159        0.0                91      toyota  ...     38.0        47.0   7788.0
# 160        0.0                91      toyota  ...     38.0        47.0   7738.0
# 161        0.0                91      toyota  ...     28.0        34.0   8358.0
# 162        0.0                91      toyota  ...     28.0        34.0   9258.0
# 163        1.0               168      toyota  ...     29.0        34.0   8058.0
# 164        1.0               168      toyota  ...     29.0        34.0   8238.0
# 165        1.0               168      toyota  ...     26.0        29.0   9298.0
# 166        1.0               168      toyota  ...     26.0        29.0   9538.0
# 167        2.0               134      toyota  ...     24.0        30.0   8449.0
# 168        2.0               134      toyota  ...     24.0        30.0   9639.0
# 169        2.0               134      toyota  ...     24.0        30.0   9989.0
# 170        2.0               134      toyota  ...     24.0        30.0  11199.0
# 171        2.0               134      toyota  ...     24.0        30.0  11549.0
# 172        2.0               134      toyota  ...     24.0        30.0  17669.0
# 173       -1.0                65      toyota  ...     29.0        34.0   8948.0
# 174       -1.0                65      toyota  ...     30.0        33.0  10698.0
# 175       -1.0                65      toyota  ...     27.0        32.0   9988.0
# 176       -1.0                65      toyota  ...     27.0        32.0  10898.0
# 177       -1.0                65      toyota  ...     27.0        32.0  11248.0
# 178        3.0               197      toyota  ...     20.0        24.0  16558.0
# 179        3.0               197      toyota  ...     19.0        24.0  15998.0
# 180       -1.0                90      toyota  ...     20.0        24.0  15690.0
# 181       -1.0               NaN      toyota  ...     19.0        24.0  15750.0
# 182        2.0               122  volkswagen  ...     37.0        46.0   7775.0
# 183        2.0               122  volkswagen  ...     27.0        34.0   7975.0
# 184        2.0                94  volkswagen  ...     37.0        46.0   7995.0
# 185        2.0                94  volkswagen  ...     27.0        34.0   8195.0
# 186        2.0                94  volkswagen  ...     27.0        34.0   8495.0
# 187        2.0                94  volkswagen  ...     37.0        42.0   9495.0
# 188        2.0                94  volkswagen  ...     26.0        32.0   9995.0
# 189        3.0               NaN  volkswagen  ...     24.0        29.0  11595.0
# 190        3.0               256  volkswagen  ...     24.0        29.0   9980.0
# 191        0.0               NaN  volkswagen  ...     19.0        24.0  13295.0
# 192        0.0               NaN  volkswagen  ...     33.0        38.0  13845.0
# 193        0.0               NaN  volkswagen  ...     25.0        31.0  12290.0
# 194       -2.0               103       volvo  ...     23.0        28.0  12940.0
# 195       -1.0                74       volvo  ...     23.0        28.0  13415.0
# 196       -2.0               103       volvo  ...     24.0        28.0  15985.0
# 197       -1.0                74       volvo  ...     24.0        28.0  16515.0
# 198       -2.0               103       volvo  ...     17.0        22.0  18420.0
# 199       -1.0                74       volvo  ...     17.0        22.0  18950.0
# 200       -1.0                95       volvo  ...     23.0        28.0  16845.0
# 201       -1.0                95       volvo  ...     19.0        25.0  19045.0
# 202       -1.0                95       volvo  ...     18.0        23.0  21485.0
# 203       -1.0                95       volvo  ...     26.0        27.0  22470.0
# 204       -1.0                95       volvo  ...     19.0        25.0  22625.0
#
# [50 rows x 26 columns]

# %% [markdown]
# # <b>Problem 4 : You need to clean the data a little bit now. Replace all column values with the values <code>?</code> and <code>n.a</code> with <code>NaN</code>

# %%
# Your code here
for col in auto.columns:
  auto.loc[auto[col].isin(['?','n.a','na']),col] = np.nan

# %%
auto.head()
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0        3.0               NaN  alfa-romero  ...     21.0        27.0  13495
# 1        3.0               NaN  alfa-romero  ...     21.0        27.0  16500
# 2        1.0               NaN  alfa-romero  ...     19.0        26.0  16500
# 3        2.0               164         audi  ...     24.0        30.0  13950
# 4        2.0               164         audi  ...     18.0        22.0  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# # <b>Problem 5 : Print the company name which manufactured the most expensive car. Also print the price of the most expensive car

# %%
auto.dtypes
# Out:
# symboling            float64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight          float64
# engine-type           object
# num-of-cylinders      object
# engine-size          float64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg             float64
# highway-mpg          float64
# price                 object
# dtype: object

# %%
auto.price = auto.price.astype(float)

# %%
# Your code here
auto.loc[auto.price == auto.price.max(),'make']
# Out:
# 74    mercedes-benz
# Name: make, dtype: object

# %% [markdown]
# # <b>Problem 6 : Calculate maximum horsepowers for each company. </b>

# %%
auto.head()
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg    price
# 0        3.0               NaN  alfa-romero  ...     21.0        27.0  13495.0
# 1        3.0               NaN  alfa-romero  ...     21.0        27.0  16500.0
# 2        1.0               NaN  alfa-romero  ...     19.0        26.0  16500.0
# 3        2.0               164         audi  ...     24.0        30.0  13950.0
# 4        2.0               164         audi  ...     18.0        22.0  17450.0
#
# [5 rows x 26 columns]

# %%
# Your code here
auto.horsepower = auto.horsepower.astype(float)
auto.groupby('make').horsepower.max()
# Out:
# make
# alfa-romero      154.0
# audi             160.0
# bmw              182.0
# chevrolet         70.0
# dodge            145.0
# honda            101.0
# isuzu             90.0
# jaguar           262.0
# mazda            135.0
# mercedes-benz    184.0
# mercury          175.0
# mitsubishi       145.0
# nissan           200.0
# peugot           142.0
# plymouth         145.0
# porsche          288.0
# renault            NaN
# saab             160.0
# subaru           111.0
# toyota           161.0
# volkswagen       110.0
# volvo            162.0
# Name: horsepower, dtype: float64

# %% [markdown]
# # <b> Problem 7 : Print the total number of cars manufactured by each company

# %%
# Your code here
auto.make.value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# jaguar            3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# # <b> Problem 8 : Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled </b>

# %%
auto.dtypes
# Out:
# symboling            float64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight          float64
# engine-type           object
# num-of-cylinders      object
# engine-size          float64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg             float64
# highway-mpg          float64
# price                float64
# dtype: object

# %%
# Your code here. Use apply and lambda
def updated(cost, eng):
  if eng == 'front':
    new_cost = cost
  else:
    new_cost = cost*2
 
  return new_cost

# %%
auto['updated_price'] = auto.apply(lambda x: updated(auto['price'], auto['normalized-losses']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ab19226061dd> in <module>()
# ----> 1 auto['updated_price'] = auto.apply(lambda x: updated(auto['price'], auto['normalized-losses']))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     303                 for i, v in enumerate(series_gen):
#     304                     # ignore SettingWithCopy here in case the user mutates
# --> 305                     results[i] = self.f(v)
#     306                     if isinstance(results[i], ABCSeries):
#     307                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-54-ab19226061dd> in <lambda>(x)
# ----> 1 auto['updated_price'] = auto.apply(lambda x: updated(auto['price'], auto['normalized-losses']))
#
# <ipython-input-51-7d548eb08fbf> in updated(cost, eng)
#       1 # Your code here. Use apply and lambda
#       2 def updated(cost, eng):
# ----> 3   if eng == 'front':
#       4     new_cost = cost
#       5   else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1328     def __nonzero__(self):
#    1329         raise ValueError(
# -> 1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1332         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# # <b>Problem 9 : Sort the dataframe by car and price columns

# %%
# Your code here

auto.sort_values(['make','price'])
# Out:
#      symboling normalized-losses  ...    price updated_price
# 0          3.0               NaN  ...  13495.0       13495.0
# 1          3.0               NaN  ...  16500.0       16500.0
# 2          1.0               NaN  ...  16500.0       16500.0
# 3          2.0               164  ...  13950.0       13950.0
# 5          2.0               NaN  ...  15250.0       15250.0
# ..         ...               ...  ...      ...           ...
# 199       -1.0                74  ...  18950.0       18950.0
# 201       -1.0                95  ...  19045.0       19045.0
# 202       -1.0                95  ...  21485.0       21485.0
# 203       -1.0                95  ...  22470.0       22470.0
# 204       -1.0                95  ...  22625.0       22625.0
#
# [205 rows x 27 columns]

# %% [markdown]
# # <b> Problem 10 : Create a new column which stores the number of doors in a car as integers.

# %%
auto.head()
# Out:
#    symboling normalized-losses  ...    price updated_price
# 0        3.0               NaN  ...  13495.0       13495.0
# 1        3.0               NaN  ...  16500.0       16500.0
# 2        1.0               NaN  ...  16500.0       16500.0
# 3        2.0               164  ...  13950.0       13950.0
# 4        2.0               164  ...  17450.0       17450.0
#
# [5 rows x 27 columns]

# %%
auto.dtypes
# Out:
# symboling            float64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight          float64
# engine-type           object
# num-of-cylinders      object
# engine-size          float64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg             float64
# highway-mpg          float64
# price                float64
# updated_price        float64
# dtype: object

# %%
auto['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
# Your code here. Use apply
calc = lambda x : 2 if x == 'two' else 4
auto['door'] = auto['num-of-doors'].apply(calc)

# %%
auto.head()
# Out:
#    symboling normalized-losses         make  ...    price updated_price door
# 0        3.0               NaN  alfa-romero  ...  13495.0       13495.0    2
# 1        3.0               NaN  alfa-romero  ...  16500.0       16500.0    2
# 2        1.0               NaN  alfa-romero  ...  16500.0       16500.0    2
# 3        2.0               164         audi  ...  13950.0       13950.0    4
# 4        2.0               164         audi  ...  17450.0       17450.0    4
#
# [5 rows x 28 columns]

# %%
auto.dtypes
# Out:
# symboling            float64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight          float64
# engine-type           object
# num-of-cylinders      object
# engine-size          float64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg             float64
# highway-mpg          float64
# price                float64
# updated_price        float64
# door                   int64
# dtype: object

# %% [markdown]
# # <b>Problem 11 : Concatenate the two data frames given below firstly row wise and secondly column wise.</b>
#
# <code>GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}</code>
#
# <code>japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}</code>

# %%
# Your code here
German = pd.DataFrame({'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]})
Japan = pd.DataFrame({'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]})

# %%
German
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
Japan
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
pd.concat((German,Japan),axis = 0)
# Out:
#        Company   Price
# 0         Ford   23845
# 1     Mercedes  171995
# 2          BMV  135925
# 3         Audi   71400
# 0       Toyota   29995
# 1        Honda   23600
# 2       Nissan   61500
# 3  Mitsubishi    58900

# %%
pd.concat((German,Japan),axis = 1)
# Out:
#     Company   Price      Company  Price
# 0      Ford   23845       Toyota  29995
# 1  Mercedes  171995        Honda  23600
# 2       BMV  135925       Nissan  61500
# 3      Audi   71400  Mitsubishi   58900
